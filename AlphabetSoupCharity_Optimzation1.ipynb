# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
#import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
AlphabetSoupCharity_Optimzation = pd.read_csv("charity_data.csv")
AlphabetSoupCharity_Optimzation.head()
# Out:
#         EIN                                      NAME  ... ASK_AMT IS_SUCCESSFUL
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB  ...    5000             1
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR  ...  108590             1
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS  ...    5000             0
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION  ...    6692             1
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT  ...  142590             1
#
# [5 rows x 12 columns]

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
AlphabetSoupCharity_Optimzation=AlphabetSoupCharity_Optimzation.drop(columns=['EIN', 'NAME'])
#charity=charity.drop(labels='EIN',axis=0)
AlphabetSoupCharity_Optimzation.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION  ... ASK_AMT IS_SUCCESSFUL
# 0              T10       Independent  ...    5000             1
# 1               T3       Independent  ...  108590             1
# 2               T5  CompanySponsored  ...    5000             0
# 3               T3  CompanySponsored  ...    6692             1
# 4               T3       Independent  ...  142590             1
#
# [5 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
AlphabetSoupCharity_Optimzation.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
#AlphabetSoupCharity_Optimzation.groupby('APPLICATION_TYPE').count()
app_types=AlphabetSoupCharity_Optimzation['APPLICATION_TYPE'].value_counts()
app_types
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T15        2
# T29        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
application_types_to_replace =app_types[app_types <50]
application_types_to_replace=application_types_to_replace.index.values

# %%
application_types_to_replace
# Out:
# array(['T9', 'T13', 'T12', 'T2', 'T14', 'T25', 'T15', 'T29', 'T17'],
#       dtype=object)

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
application_types_to_replace =app_types[app_types <50]
application_types_to_replace=application_types_to_replace.index.values
# Replace in dataframe
for app in application_types_to_replace:
    AlphabetSoupCharity_Optimzation['APPLICATION_TYPE'] = AlphabetSoupCharity_Optimzation['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
AlphabetSoupCharity_Optimzation['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# T13         66
# Other       54
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
#AlphabetSoupCharity_Optimzation.groupby('CLASSIFICATION').count()
class_types=AlphabetSoupCharity_Optimzation['CLASSIFICATION'].value_counts()
class_types
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4500        1
# C4120        1
# C2190        1
# C2150        1
# C1370        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
class_types[class_types >1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1237        9
# C1235        9
# C7210        7
# C2400        6
# C4100        6
# C1720        6
# C1257        5
# C1600        5
# C2710        3
# C0           3
# C1260        3
# C1234        2
# C1256        2
# C1246        2
# C1267        2
# C3200        2
# Name: CLASSIFICATION, dtype: int64

# %%
 classifications_to_replace =class_types[class_types <100]
 classifications_to_replace=classifications_to_replace.index.values
classifications_to_replace
# Out:
# array(['C2800', 'C7100', 'C1300', 'C1280', 'C1230', 'C1400', 'C7200',
#        'C2300', 'C1240', 'C8000', 'C7120', 'C1500', 'C1800', 'C6000',
#        'C1250', 'C8200', 'C1238', 'C1278', 'C1237', 'C1235', 'C7210',
#        'C4100', 'C1720', 'C2400', 'C1257', 'C1600', 'C1260', 'C2710',
#        'C0', 'C1246', 'C3200', 'C1234', 'C1267', 'C1256', 'C2500',
#        'C2600', 'C2570', 'C2170', 'C6100', 'C1732', 'C1820', 'C8210',
#        'C5200', 'C1570', 'C2561', 'C2380', 'C1245', 'C1580', 'C1248',
#        'C1728', 'C4200', 'C1283', 'C1900', 'C1236', 'C3700', 'C4500',
#        'C4120', 'C2190', 'C2150', 'C1370'], dtype=object)

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
#classifications_to_replace =class_types[class_types <100]
#classifications_to_replace=classifications_to_replace.index.values

# Replace in dataframe
for cls in classifications_to_replace:
    AlphabetSoupCharity_Optimzation['CLASSIFICATION'] = AlphabetSoupCharity_Optimzation['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
AlphabetSoupCharity_Optimzation['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
application_dummies = pd.get_dummies(AlphabetSoupCharity_Optimzation)
application_dummies
# Out:
#        STATUS   ASK_AMT  ...  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0           1      5000  ...                         1                         0
# 1           1    108590  ...                         1                         0
# 2           1      5000  ...                         1                         0
# 3           1      6692  ...                         1                         0
# 4           1    142590  ...                         1                         0
# ...       ...       ...  ...                       ...                       ...
# 34294       1      5000  ...                         1                         0
# 34295       1      5000  ...                         1                         0
# 34296       1      5000  ...                         1                         0
# 34297       1      5000  ...                         1                         0
# 34298       1  36500179  ...                         1                         0
#
# [34299 rows x 46 columns]

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
y = application_dummies["IS_SUCCESSFUL"].values
X = application_dummies.drop(["IS_SUCCESSFUL"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
no_input_features = X_train_scaled.shape[1]
no_input_features
# Out:
# 45

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()
nn_model = tf.keras.models.Sequential()
# First hidden layer and input layer
nn_model.add(tf.keras.layers.Dense(units=90, activation="relu", input_dim=no_input_features))
# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=60, activation="relu"))

# Output layer

nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# nn_model.build()
# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 90)                4140
#
#  dense_4 (Dense)             (None, 60)                5460
#
#  dense_5 (Dense)             (None, 1)                 61
#
# =================================================================
# Total params: 9,661
# Trainable params: 9,661
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE 
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50) #, callbacks=)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5721 - accuracy: 0.7244
# Epoch 2/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5569 - accuracy: 0.7297
# Epoch 3/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5537 - accuracy: 0.7305
# Epoch 4/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5513 - accuracy: 0.7318
# Epoch 5/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5498 - accuracy: 0.7328
# Epoch 6/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5492 - accuracy: 0.7333
# Epoch 7/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5486 - accuracy: 0.7335
# Epoch 8/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5475 - accuracy: 0.7338
# Epoch 9/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5464 - accuracy: 0.7349
# Epoch 10/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7352
# Epoch 11/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5457 - accuracy: 0.7355
# Epoch 12/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5446 - accuracy: 0.7348
# Epoch 13/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5454 - accuracy: 0.7359
# Epoch 14/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5447 - accuracy: 0.7365
# Epoch 15/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5450 - accuracy: 0.7353
# Epoch 16/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5436 - accuracy: 0.7360
# Epoch 17/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5439 - accuracy: 0.7355
# Epoch 18/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5433 - accuracy: 0.7362
# Epoch 19/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5432 - accuracy: 0.7369
# Epoch 20/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5427 - accuracy: 0.7369
# Epoch 21/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5422 - accuracy: 0.7372
# Epoch 22/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7381
# Epoch 23/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5420 - accuracy: 0.7371
# Epoch 24/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5422 - accuracy: 0.7383
# Epoch 25/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5412 - accuracy: 0.7373
# Epoch 26/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5416 - accuracy: 0.7376
# Epoch 27/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5412 - accuracy: 0.7379
# Epoch 28/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5408 - accuracy: 0.7383
# Epoch 29/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5406 - accuracy: 0.7391
# Epoch 30/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5408 - accuracy: 0.7381
# Epoch 31/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5403 - accuracy: 0.7385
# Epoch 32/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5405 - accuracy: 0.7384
# Epoch 33/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5401 - accuracy: 0.7378
# Epoch 34/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5399 - accuracy: 0.7381
# Epoch 35/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5399 - accuracy: 0.7387
# Epoch 36/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5391 - accuracy: 0.7382
# Epoch 37/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5394 - accuracy: 0.7399
# Epoch 38/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.7390
# Epoch 39/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.7393
# Epoch 40/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.7389
# Epoch 41/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5390 - accuracy: 0.7393
# Epoch 42/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7393
# Epoch 43/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5386 - accuracy: 0.7389
# Epoch 44/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5387 - accuracy: 0.7393
# Epoch 45/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5380 - accuracy: 0.7401
# Epoch 46/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7400
# Epoch 47/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5377 - accuracy: 0.7397
# Epoch 48/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5381 - accuracy: 0.7399
# Epoch 49/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7408
# Epoch 50/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5375 - accuracy: 0.7413

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5541 - accuracy: 0.7257 - 495ms/epoch - 2ms/step
# Loss: 0.554104745388031, Accuracy: 0.7257142663002014

# %%
 
#  YOUR CODE GOES HERE
nn_model.save("Neuralhomework1.h5")
